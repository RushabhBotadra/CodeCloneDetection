# %% [markdown]
# DataSet Preparation from GPTCloneBench dataset

# %%
import os
from pathlib import Path
import re
import pandas as pd
import numpy as np

# %%
# Split file
def split_file(content):
    clone1,_, clone2 = content.partition("\n\n\n")
    clone1 = clone1.strip().strip("\n")
    clone2 = clone2.strip().strip("\n")
    return clone1, clone2

# %%
# Load the files from the dataset
def load_clone_files(root_dir, languages):
    base_path = Path(root_dir) / "standalone"

    if not base_path.exists():
        raise FileNotFoundError(f"Base directory not found: {base_path}")
    else:
        print("Base Path:", base_path.absolute())

    file_pattern = re.compile(
    r'.*(true_semantic_clones|false_semantic_clones)[\\/]'
    r'(?P<language>py|java|cs)[\\/]'
    r'(?:prompt_(?P<prompt>\d+)[\\/])?'
    r'(?:(?P<clonetype>MT3|T4|T1|T2)[\\/])?'
    r'(?:Clone_|Gpt_false_pair_)(?P<id>\d+)\.(py|java|cs)$',
    re.IGNORECASE
)

    clones = []
    processed_files = 0

    for clone_type in ['true_semantic_clones', 'false_semantic_clones']:
        type_path = base_path / clone_type

        if not type_path.exists():
            print(f"Directory not found - {type_path}")
            continue
        else:
            print(f"\nProcessing {clone_type} at {type_path}")

        for lang in languages:
            lang_path = type_path / lang

            if not lang_path.exists():
                print(f"  Directory not found - {lang_path}")
                continue
            else:
                print(f"  Processing {lang} files at {lang_path}")

            for file in lang_path.glob("**/*.*"):
                file_str = str(file)
                print(f"    Processing: {file_str}")

                if (lang == 'py' and not file_str.lower().endswith('.py')) or \
                    (lang == 'java' and not file_str.lower().endswith('.java')) or \
                    (lang == 'cs' and not file_str.lower().endswith('.cs')):
                    print(f"    Skipping non-{lang} file")
                    continue

                match = file_pattern.search(file_str)
                if not match:
                    print(f"    File path doesn't match expected pattern")
                    continue

                groups = match.groupdict()
                print(f"    Matched groups: {groups}")

                try:
                    with open(file, 'r', encoding='utf-8') as f:
                        content = f.read()
                except Exception as e:
                    print(f"    Failed to read file: {str(e)}")
                    continue

                clone1, clone2 = split_file(content)

                if not clone1 or not clone2:
                    print(f"Could not split {lang} content into two clones")
                    continue

                record = {
                    'file_path': file_str,
                    'language': lang.lower(),
                    'clone_category': clone_type.lower(),
                    'clone1': clone1,
                    'clone2': clone2,
                    'prompt': groups['prompt'],
                    'clonetype': groups['clonetype'],
                    # 'id': groups['id']
                }
                clones.append(record)
                processed_files += 1
                print(f"    File {processed_files} processed successfully!")

    if not clones:
        raise ValueError("No valid clone files were processed")

    print("Clones", len(clones))
    df = pd.DataFrame(clones)
    # df.sort_values(by='id', inplace=True)
    print(f"\nSuccessfully processed {len(df)} clone pairs")
    return df

# %%
dataset_path = r"/content/drive/MyDrive/SEM3_DISSERTATION"

print("Loading clone files...")
#Added cs lan
clones_df = load_clone_files(dataset_path, languages=('py', 'java', 'cs'))
# Out:
# Streaming output truncated to the last 5000 lines.
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2426'}
#     File 42310 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4462.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4462'}
#     File 42311 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4173.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4173'}
#     File 42312 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1917.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1917'}
#     File 42313 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_830.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '830'}
#     File 42314 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2169.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2169'}
#     File 42315 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4104.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4104'}
#     File 42316 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4021.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4021'}
#     File 42317 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1602.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1602'}
#     File 42318 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2004.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2004'}
#     File 42319 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3763.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3763'}
#     File 42320 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2808.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2808'}
#     File 42321 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2266.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2266'}
#     File 42322 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2737.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2737'}
#     File 42323 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3731.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3731'}
#     File 42324 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1562.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1562'}
#     File 42325 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4000.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4000'}
#     File 42326 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3745.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3745'}
#     File 42327 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3009.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3009'}
#     File 42328 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3754.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3754'}
#     File 42329 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4611.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4611'}
#     File 42330 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3387.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3387'}
#     File 42331 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4398.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4398'}
#     File 42332 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1538.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1538'}
#     File 42333 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3517.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3517'}
#     File 42334 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_389.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '389'}
#     File 42335 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3322.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3322'}
#     File 42336 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1669.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1669'}
#     File 42337 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3742.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3742'}
#     File 42338 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_699.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '699'}
#     File 42339 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_725.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '725'}
#     File 42340 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_697.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '697'}
#     File 42341 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1031.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1031'}
#     File 42342 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1761.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1761'}
#     File 42343 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1381.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1381'}
#     File 42344 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3333.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3333'}
#     File 42345 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1156.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1156'}
#     File 42346 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1708.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1708'}
#     File 42347 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4093.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4093'}
#     File 42348 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1407.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1407'}
#     File 42349 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_653.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '653'}
#     File 42350 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_235.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '235'}
#     File 42351 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4294.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4294'}
#     File 42352 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4404.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4404'}
#     File 42353 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1694.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1694'}
#     File 42354 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3027.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3027'}
#     File 42355 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_944.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '944'}
#     File 42356 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3041.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3041'}
#     File 42357 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3716.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3716'}
#     File 42358 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2359.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2359'}
#     File 42359 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1999.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1999'}
#     File 42360 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_280.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '280'}
#     File 42361 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1449.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1449'}
#     File 42362 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1573.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1573'}
#     File 42363 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2599.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2599'}
#     File 42364 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2178.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2178'}
#     File 42365 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2185.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2185'}
#     File 42366 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1232.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1232'}
#     File 42367 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4071.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4071'}
#     File 42368 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_601.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '601'}
#     File 42369 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2983.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2983'}
#     File 42370 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2054.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2054'}
#     File 42371 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3834.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3834'}
#     File 42372 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_777.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '777'}
#     File 42373 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2691.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2691'}
#     File 42374 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1327.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1327'}
#     File 42375 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1909.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1909'}
#     File 42376 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2541.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2541'}
#     File 42377 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4354.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4354'}
#     File 42378 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4591.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4591'}
#     File 42379 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3245.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3245'}
#     File 42380 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1422.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1422'}
#     File 42381 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4096.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4096'}
#     File 42382 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2608.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2608'}
#     File 42383 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1055.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1055'}
#     File 42384 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3421.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3421'}
#     File 42385 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_536.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '536'}
#     File 42386 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4100.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4100'}
#     File 42387 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1229.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1229'}
#     File 42388 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1719.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1719'}
#     File 42389 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2570.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2570'}
#     File 42390 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3016.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3016'}
#     File 42391 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1502.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1502'}
#     File 42392 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4528.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4528'}
#     File 42393 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3498.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3498'}
#     File 42394 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1749.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1749'}
#     File 42395 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2693.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2693'}
#     File 42396 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2321.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2321'}
#     File 42397 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1045.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1045'}
#     File 42398 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1809.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1809'}
#     File 42399 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3359.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3359'}
#     File 42400 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1000.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1000'}
#     File 42401 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4543.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4543'}
#     File 42402 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1379.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1379'}
#     File 42403 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_527.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '527'}
#     File 42404 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1888.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1888'}
#     File 42405 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_458.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '458'}
#     File 42406 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3869.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3869'}
#     File 42407 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4418.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4418'}
#     File 42408 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2277.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2277'}
#     File 42409 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1107.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1107'}
#     File 42410 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1053.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1053'}
#     File 42411 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1032.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1032'}
#     File 42412 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_819.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '819'}
#     File 42413 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_275.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '275'}
#     File 42414 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3281.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3281'}
#     File 42415 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3791.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3791'}
#     File 42416 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3561.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3561'}
#     File 42417 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3694.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3694'}
#     File 42418 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1635.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1635'}
#     File 42419 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2979.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2979'}
#     File 42420 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_41.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '41'}
#     File 42421 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4620.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4620'}
#     File 42422 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1160.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1160'}
#     File 42423 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1675.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1675'}
#     File 42424 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2928.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2928'}
#     File 42425 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1393.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1393'}
#     File 42426 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3014.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3014'}
#     File 42427 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3191.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3191'}
#     File 42428 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4030.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4030'}
#     File 42429 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2612.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2612'}
#     File 42430 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4136.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4136'}
#     File 42431 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3930.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3930'}
#     File 42432 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2776.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2776'}
#     File 42433 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3228.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3228'}
#     File 42434 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1589.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1589'}
#     File 42435 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_12.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '12'}
#     File 42436 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2996.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2996'}
#     File 42437 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_445.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '445'}
#     File 42438 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3648.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3648'}
#     File 42439 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_424.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '424'}
#     File 42440 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_337.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '337'}
#     File 42441 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3469.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3469'}
#     File 42442 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_212.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '212'}
#     File 42443 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3248.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3248'}
#     File 42444 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3751.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3751'}
#     File 42445 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2034.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2034'}
#     File 42446 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2393.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2393'}
#     File 42447 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3919.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3919'}
#     File 42448 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1604.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1604'}
#     File 42449 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2882.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2882'}
#     File 42450 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4192.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4192'}
#     File 42451 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2827.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2827'}
#     File 42452 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2111.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2111'}
#     File 42453 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2854.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2854'}
#     File 42454 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4381.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4381'}
#     File 42455 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_105.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '105'}
#     File 42456 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1700.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1700'}
#     File 42457 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4514.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4514'}
#     File 42458 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3584.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3584'}
#     File 42459 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_211.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '211'}
#     File 42460 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3323.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3323'}
#     File 42461 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4188.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4188'}
#     File 42462 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4002.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4002'}
#     File 42463 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1172.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1172'}
#     File 42464 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1641.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1641'}
#     File 42465 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3392.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3392'}
#     File 42466 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4524.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4524'}
#     File 42467 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2168.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2168'}
#     File 42468 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_426.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '426'}
#     File 42469 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3290.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3290'}
#     File 42470 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_497.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '497'}
#     File 42471 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2884.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2884'}
#     File 42472 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2835.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2835'}
#     File 42473 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1427.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1427'}
#     File 42474 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2072.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2072'}
#     File 42475 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2749.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2749'}
#     File 42476 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2964.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2964'}
#     File 42477 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1251.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1251'}
#     File 42478 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4175.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4175'}
#     File 42479 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_583.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '583'}
#     File 42480 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3050.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3050'}
#     File 42481 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1403.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1403'}
#     File 42482 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_991.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '991'}
#     File 42483 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2502.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2502'}
#     File 42484 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2057.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2057'}
#     File 42485 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1955.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1955'}
#     File 42486 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2574.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2574'}
#     File 42487 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1552.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1552'}
#     File 42488 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2820.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2820'}
#     File 42489 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1139.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1139'}
#     File 42490 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3492.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3492'}
#     File 42491 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4067.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4067'}
#     File 42492 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3612.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3612'}
#     File 42493 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2534.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2534'}
#     File 42494 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3432.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3432'}
#     File 42495 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1438.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1438'}
#     File 42496 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1941.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1941'}
#     File 42497 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1806.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1806'}
#     File 42498 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2136.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2136'}
#     File 42499 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2231.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2231'}
#     File 42500 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2332.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2332'}
#     File 42501 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4534.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4534'}
#     File 42502 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1900.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1900'}
#     File 42503 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3232.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3232'}
#     File 42504 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4361.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4361'}
#     File 42505 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3460.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3460'}
#     File 42506 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2625.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2625'}
#     File 42507 processed successfully!
# ...
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1060'}
#     File 43910 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1851.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1851'}
#     File 43911 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2645.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2645'}
#     File 43912 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2369.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2369'}
#     File 43913 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3033.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3033'}
#     File 43914 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1319.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1319'}
#     File 43915 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3866.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3866'}
#     File 43916 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4491.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4491'}
#     File 43917 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4600.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4600'}
#     File 43918 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2648.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2648'}
#     File 43919 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2647.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2647'}
#     File 43920 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3927.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3927'}
#     File 43921 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_799.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '799'}
#     File 43922 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2688.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2688'}
#     File 43923 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2114.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2114'}
#     File 43924 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3960.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3960'}
#     File 43925 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4468.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4468'}
#     File 43926 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1699.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1699'}
#     File 43927 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_241.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '241'}
#     File 43928 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_379.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '379'}
#     File 43929 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4149.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4149'}
#     File 43930 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1841.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1841'}
#     File 43931 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_834.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '834'}
#     File 43932 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1857.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1857'}
#     File 43933 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2420.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2420'}
#     File 43934 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2635.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2635'}
#     File 43935 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2066.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2066'}
#     File 43936 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2689.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2689'}
#     File 43937 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_963.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '963'}
#     File 43938 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1288.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1288'}
#     File 43939 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1581.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1581'}
#     File 43940 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3799.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3799'}
#     File 43941 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_60.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '60'}
#     File 43942 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_288.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '288'}
#     File 43943 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4410.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4410'}
#     File 43944 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4567.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4567'}
#     File 43945 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3881.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3881'}
#     File 43946 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3532.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3532'}
#     File 43947 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4153.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4153'}
#     File 43948 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2561.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2561'}
#     File 43949 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_743.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '743'}
#     File 43950 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3729.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3729'}
#     File 43951 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4421.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4421'}
#     File 43952 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_835.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '835'}
#     File 43953 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2146.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2146'}
#     File 43954 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3699.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3699'}
#     File 43955 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2208.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2208'}
#     File 43956 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1499.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1499'}
#     File 43957 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1514.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1514'}
#     File 43958 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_258.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '258'}
#     File 43959 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3760.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3760'}
#     File 43960 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_708.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '708'}
#     File 43961 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4014.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4014'}
#     File 43962 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1800.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1800'}
#     File 43963 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1298.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1298'}
#     File 43964 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2900.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2900'}
#     File 43965 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2290.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2290'}
#     File 43966 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_4376.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '4376'}
#     File 43967 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3064.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3064'}
#     File 43968 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_3573.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '3573'}
#     File 43969 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2920.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2920'}
#     File 43970 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_1923.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '1923'}
#     File 43971 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_869.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '869'}
#     File 43972 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_2395.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '2395'}
#     File 43973 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_741.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '741'}
#     File 43974 processed successfully!
#     Processing: /content/drive/MyDrive/SEM3_DISSERTATION/standalone/false_semantic_clones/cs/Gpt_false_pair_415.cs
#     Matched groups: {'language': 'cs', 'prompt': None, 'clonetype': None, 'id': '415'}
#     File 43975 processed successfully!
# Clones 43975
#
# Successfully processed 43975 clone pairs

# %%
clones_df.head(1)
# Out:
#                                            file_path language  \
# 0  /content/drive/MyDrive/SEM3_DISSERTATION/stand...       py
#
#          clone_category                                             clone1  \
# 0  true_semantic_clones  def __getitem__(self, key) :\n\tif isinstance(...
#
#                                               clone2 prompt clonetype
# 0  def __getitem__(self, key) :\n\tif isinstance(...      2       MT3

# %% [markdown]
# Balance the dataset

# %%
def balance_clone_data(df):
    # Separate the datasets
    true_df = df[df['clone_category'] == 'true_semantic_clones'].copy()
    false_df = df[df['clone_category'] == 'false_semantic_clones'].copy()

    # Process false semantic clones (balance by language only)
    if len(false_df) > 0:
        false_groups = false_df.groupby('language')
        false_min_size = false_groups.size().min()
        print(f"Balancing false semantic clones to {false_min_size} per language")

        balanced_false = []
        for lang, group in false_groups:
            if len(group) < false_min_size:
                print(f"Warning: Language {lang} has only {len(group)} false samples")
                sampled = group
            else:
                sampled = group.sample(false_min_size, random_state=42)
            balanced_false.append(sampled)
    else:
        print("No false semantic clones found")
        balanced_false = []

    # Process true semantic clones (balance by prompt+clonetype across languages)
    if len(true_df) > 0:
        # First group by prompt and clonetype
        prompt_clone_groups = true_df.groupby(['prompt', 'clonetype'])

        balanced_true = []
        for (prompt, clonetype), group in prompt_clone_groups:
            # Then group by language within each prompt+clonetype group
            lang_groups = group.groupby('language')
            min_size = lang_groups.size().min()

            print(f"Balancing (prompt={prompt}, clonetype={clonetype}) to {min_size} per language")

            for lang, lang_group in lang_groups:
                if len(lang_group) < min_size:
                    print(f"Warning: Language {lang} has only {len(lang_group)} samples for (prompt={prompt}, clonetype={clonetype})")
                    sampled = lang_group
                else:
                    sampled = lang_group.sample(min_size, random_state=42)
                balanced_true.append(sampled)
    else:
        print("No true semantic clones found")
        balanced_true = []

    # Combine results
    balanced_df = pd.concat(balanced_true + balanced_false).reset_index(drop=True)

    # Verification
    print("\nFinal Distribution:")
    if len(balanced_true) > 0:
        print("True semantic clones:")
        print(balanced_df[balanced_df['clone_category'] == 'true_semantic_clones']
              .groupby(['language', 'prompt', 'clonetype']).size())
    if len(balanced_false) > 0:
        print("\nFalse semantic clones:")
        print(balanced_df[balanced_df['clone_category'] == 'false_semantic_clones']
              .groupby('language').size())

    return balanced_df

# %%
balanced_df = balance_clone_data(clones_df)
# Out:
# Balancing false semantic clones to 4231 per language
# Balancing (prompt=1, clonetype=MT3) to 721 per language
# Balancing (prompt=1, clonetype=T4) to 310 per language
# Balancing (prompt=2, clonetype=MT3) to 2389 per language
# Balancing (prompt=2, clonetype=T4) to 5196 per language
#
# Final Distribution:
# True semantic clones:
# language  prompt  clonetype
# cs        1       MT3           721
#                   T4            310
#           2       MT3          2389
#                   T4           5196
# java      1       MT3           721
#                   T4            310
#           2       MT3          2389
#                   T4           5196
# py        1       MT3           721
#                   T4            310
#           2       MT3          2389
#                   T4           5196
# dtype: int64
#
# False semantic clones:
# language
# cs      4231
# java    4231
# py      4231
# dtype: int64

# %%
python_count = balanced_df[balanced_df['language'] == 'py'].shape[0]
java_count = balanced_df[balanced_df['language'] == 'java'].shape[0]
# Added cs lan
cs_count = balanced_df[balanced_df['language'] == 'cs'].shape[0]

print("Python entries:", python_count)
print("Java entries:", java_count)
# Added cs lan
print("C# entries:", cs_count)
# Out:
# Python entries: 12847
# Java entries: 12847
# C# entries: 12847

# %%
pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein)
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.13.0

# %% [markdown]
# Non-Clone Pair Creation using Normalized Levenshtein Distance

# %%
import Levenshtein

# Normalized Levenshtein distance ([0,1])
def normalized_levenshtein(s1, s2):
    distance = Levenshtein.distance(s1, s2)
    max_len = max(len(s1), len(s2))
    return distance / max_len if max_len > 0 else 0
# Create Dissimilar Pairs
def create_dissimilar_pairs(df, similarity_threshold=0.5):
    dissimilar_pairs = []

# Added cs lan
    for lang in ['py', 'java', 'cs']:
        print(f"\nCreating dissimilar pairs for {lang}")
        lang_df = df[df['language'] == lang]

        print("Initial:", lang, len(lang_df))
        if lang_df.empty:
            print(f"No data for {lang}, skipping dissimilar pair creation")
            continue

        num_pairs = len(lang_df)
        pairs = []
        used_pairs = set()
        potential_clones = 0

        for i in range(num_pairs):
            j = num_pairs - 1 - i
            if i == j:
                continue

            clone1 = lang_df.iloc[i]['clone1']
            clone2 = lang_df.iloc[j]['clone2']
            file1 = lang_df.iloc[i]['file_path']
            file2 = lang_df.iloc[j]['file_path']

            if file1 != file2:
                pair_key = tuple(sorted([clone1, clone2]))
                if pair_key not in used_pairs:
                    distance = normalized_levenshtein(clone1, clone2)
                    # is_clone = 0 if distance > similarity_threshold else 1
                    # if is_clone == 1:
                    #     potential_clones += 1

                    # pairs.append({
                    #     'clone1': clone1,
                    #     'clone2': clone2,
                    #     'language': lang,
                    #     'is_semantic_clone': is_clone,
                    #     'levenshtein_distance': distance
                    # })
                    # used_pairs.add(pair_key)
                    if distance > similarity_threshold:
                        pairs.append({
                            'clone1': clone1,
                            'clone2': clone2,
                            'language': lang,
                            'is_semantic_clone': 0,
                            'levenshtein_distance': distance
                        })
                        used_pairs.add(pair_key)

        pairs_df = pd.DataFrame(pairs)

        if pairs_df.empty:
            print(f"  {lang}: No dissimilar pairs generated")
            continue

        pairs_df = pairs_df.drop_duplicates(subset=['clone1', 'clone2'])
        print(f"  {lang}: Generated {len(pairs_df)} pairs")
        print(f"  - Confirmed dissimilar (0): {len(pairs_df) - potential_clones}")
        # print(f"  - Potential clones (1): {potential_clones}")
        print(f"  - Average Levenshtein distance: {pairs_df['levenshtein_distance'].mean():.2f}")

        dissimilar_pairs.append(pairs_df)

    if not dissimilar_pairs:
        print("No dissimilar pairs generated")
        return pd.DataFrame(columns=['language', 'clone1', 'clone2', 'is_semantic_clone', 'levenshtein_distance'])

    return pd.concat(dissimilar_pairs, ignore_index=True)

# %%
dissimilar_pairs = create_dissimilar_pairs(balanced_df)
# Out:
# Creating dissimilar pairs for py
# Initial: py 12847
#   py: Generated 12830 pairs
#   - Confirmed dissimilar (0): 12830
#   - Average Levenshtein distance: 0.80
#
# Creating dissimilar pairs for java
# Initial: java 12847
#   java: Generated 12787 pairs
#   - Confirmed dissimilar (0): 12787
#   - Average Levenshtein distance: 0.75
#
# Creating dissimilar pairs for cs
# Initial: cs 12847
#   cs: Generated 12810 pairs
#   - Confirmed dissimilar (0): 12810
#   - Average Levenshtein distance: 0.76

# %% [markdown]
# Combine Clone + Non-Clone Pairs

# %%
def combine_dataset(df, dissimilar_pairs):
    if df.empty and dissimilar_pairs.empty:
        raise ValueError("Both input DataFrames are empty")

    df['is_semantic_clone'] = 1

    original_df = df[['language', 'clone1', 'clone2', 'is_semantic_clone']]
    original_df.columns = ['language', 'clone1', 'clone2', 'is_semantic_clone']

    dissimilar_df = dissimilar_pairs[['language', 'clone1', 'clone2', 'is_semantic_clone']]
    dissimilar_df.columns = ['language', 'clone1', 'clone2', 'is_semantic_clone']

    final_df = pd.concat([original_df, dissimilar_df], ignore_index=True)

    print(f"Final dataset size: {len(final_df)} pairs")
    print(f"  Original pairs: {len(original_df)}")
    print(f"  Dissimilar pairs: {len(dissimilar_pairs)}")

    return final_df

# %%
print("\nCreating final dataset...")
final_df = combine_dataset(balanced_df, dissimilar_pairs)
# Out:
# Creating final dataset...
# Final dataset size: 76968 pairs
#   Original pairs: 38541
#   Dissimilar pairs: 38427

# %%
# Save results

# Define the output path
output_path = "/content/drive/MyDrive/SEM3_DISSERTATION/output/Updated/clone_dataset.csv"

# Extract the directory path from the output_path
output_dir = Path(output_path).parent

# Create the directory if it doesn't exist, including any necessary parent directories
os.makedirs(output_dir, exist_ok=True)

# Now save the DataFrame to the file
final_df.to_csv(output_path, index=False)
print(f"\nDataset successfully saved to {output_path}")

# Show sample
print("\nSample of the dataset:")
print(final_df.head())

# Show label distribution
print("\nLabel distribution:")
print(final_df['is_semantic_clone'].value_counts())
# Out:
# Dataset successfully saved to /content/drive/MyDrive/SEM3_DISSERTATION/output/Updated/clone_dataset.csv
#
# Sample of the dataset:
#   language                                             clone1  \
# 0       cs  public void doWork () {\n    int h = 0;\n    d...
# 1       cs  private static bool GetFileNameFromHandle (Int...
# 2       cs  private void button6_Click (object sender, Eve...
# 3       cs  public static string Generate () {\n    var pw...
# 4       cs  public override int Read (char [] buffer, int ...
#
#                                               clone2  is_semantic_clone
# 0  public void doWork()\n{\n    int h = 0;\n    w...                  1
# 1  private static bool GetFileNameFromHandle (Int...                  1
# 2  private void button6_Click (object sender, Eve...                  1
# 3  public static string Generate () {\n    var pw...                  1
# 4  public override int Read(char [] buffer, int i...                  1
#
# Label distribution:
# is_semantic_clone
# 1    38541
# 0    38427
# Name: count, dtype: int64
